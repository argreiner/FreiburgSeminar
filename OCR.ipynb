# %%
import cv2
import numpy as np
import pytesseract
from pandas import DataFrame

# %%
pre = 'InhaltBL/BLVolIV'
post = '.png'
InhaltBL =''
for c in np.arange(1,3):
    file = pre+str(c)+post
    img_cv = cv2.imread(file,0)
    img_rgb = cv2.cvtColor(img_cv, cv2.COLOR_BGR2RGB)
    InhaltBL += pytesseract.image_to_string(img_rgb, lang='deu')

# By default OpenCV stores images in BGR format and since pytesseract assumes RGB format,
# we need to convert from BGR to RGB format/mode:
# img_rgb = cv2.cvtColor(img_cv, cv2.COLOR_BGR2RGB)
#print(pytesseract.image_to_string(img_rgb))
# OR
#img_rgb = Image.frombytes('RGB', img_cv.shape[:2], img_cv, 'raw', 'BGR', 0, 0)
#print(pytesseract.image_to_string(img_rgb))

# %%
with open("InhaltBLVolIV.txt", "w") as text_file:
    text_file.write(InhaltBL)

# %%
InhaltBL
# Out:
# '28.\n\n29.\n\n30.\n\n27.4.\n27.5,\n\nZT.\n\n27.3.4. Residuensatz 2222020.\n27.3.5. CAUCHYsche Integralformel .. 2.222222...\nUnendliche Reihen, Potenzteihen 2222222...\nLAURENTsche Reihe 2...\n\nUmkehrfunktionen, trigonometrische Funktionen und\nHyperbelfunktionen . . 22.2222\n27.6.1. Potenzfunktionen mit natürlichen Exponenten\nund deren Umkehrfunktionen .. 22222222...\n27.6.2. Exponentialfunktionen und Logarithmus-\nfunktion 22.00 nn\n27.6.3. Trigonometrische Funktionen und Hyperbel-\nfunktionen . 2... oo on\nEbene Strömungen 2.\n\n27.8. Analytische Fortsetzung 2.2222 on\nAufgaben zum 27. Abschnitt 2.202 Con\n\nMetrische Räume, normierte Vektorräume und\nSkalarprodukträume 2.2.2222 02 on\n28.1. Metrische Räume 2... on\n28.2. Normierte Vektorräume 22 en\n28.3 Skalarprodukträume 2.2.22 2 c on\nAufgaben zum 28. Abschnitt 2.2 on\n\nFouriesreihen 2... 02.2 Ir ser. ee.\n29.1. Approximationseigenschaften von Fourierreihen ........\n29.2. Normierte Orthogonalsysteme . 2.222 cc err..\n29.3. Konvergenzeigenschaften von Fourierteihen ..........\n29.4. Beispiele von Fourierreihen . 2.2.2.2: 22 cos.\nAufgaben zum 29. Abschnitt 2220\n\nLineare Operatoren 2.2 o\n\n30.1.\n\n30.2.\n30.3.\n30.4.\n30.\n\nFourier- und Laplacetransformation als Beispiele\n\nlinearer Operatoren .. 22.22 o on\nLineare Operatoren (Abbildungen, Transformationen) s:\nNEUMANNsche Reihe . 2... 22 cc man\nAnwendung von inversen Operatoren 2 22 cn.\nIntegraltransformationen . 2.2.22 cn.\n\nAufgaben zum 30. Abschnitt oem\nLineare Randwertprobleme .........::2ceeeeeeeneen\n31.1. Unterschiede zwischen Anfangswert- und Randwert-\nproblemen ua: : 25 sc weme ee onmennn ec. namen\n31.2. Homogenisierung von Randwertproblemen ...........\n31.3. Lösbarkeit von Randwertproblemen ........... 2...\n31.4. Randwertprobleme mit Differentialgleichungen zweiter\nOrdnung und STURMschen Randbedingungen .........\n31.5. Randwertprobleme mit Differentialgleichungen n-ter\nOrdnung (n=2,3,...) und beliebigen homogenen\nRandbedingungen ......: 2222er eeeeeeneeenen\nAufgaben zum 31. Abschnitt 2.2.20 eeeeeeeeeenenen\n\nLineare Eigenwertprobleme ............2reeereeeenene\n32.1. Grundlegende Eigenschaften von Eigenwertproblemen .\n32.2. Eigenwerte von HERMITEschen Matrizen. ...........-\n32.3. FREDHOLMsche Integralgleichungen mit ausgearteten\n\nKernen? era a ee ne Eur.\n32.4. Eigenwertprobleme mit linearen Differential-\n\ngleichungen nur: das duesshesnmann en den\n32.5. Abschließende Sätze .......:222ceeeeenneenn nen\nAufgaben zum 32. Abschnitt .......22eeeeeeennenene\n'

