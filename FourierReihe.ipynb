# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
T = np.linspace(0.,1.0,1000)
omega = 2.0*np.pi*np.arange(100)
ampsin = np.random.rand(100)
ampcos = np.random.rand(100)
y = np.zeros((1000))

# %%
# %matplotlib notebook

for i in np.arange(100):
    y = y + ampcos[i]*np.cos(omega[i]*T) + ampsin[i]*np.sin(omega[i]*T)  # y+= np.sin(omega[i]*T)
#
plt.plot(T,y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
y=np.random.rand(1000)
f = np.fft.fft(y)
plt.plot(np.real(f))
plt.plot(y*50)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
plt.plot(np.fft.ifft(f)-y)
# Out:
# <img src="data:image/png;base64,..." width="640">
# /Users/greiner/Library/Python/3.8/lib/python/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
omega
# Out:
# array([  0.        ,   6.28318531,  12.56637061,  18.84955592,
#         25.13274123,  31.41592654,  37.69911184,  43.98229715,
#         50.26548246,  56.54866776,  62.83185307,  69.11503838,
#         75.39822369,  81.68140899,  87.9645943 ,  94.24777961,
#        100.53096491, 106.81415022, 113.09733553, 119.38052084])

# %%
np.exp(f[1])+np.exp(f[-1])
# Out:
# (-9.352795999422352-4.440892098500626e-16j)

# %%
# Out:
# (1.5700053602692978+499.7465834284344j)
