# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n = 1000
T = np.linspace(0.,1.0,n)
omega = 2.0*np.pi*np.arange(n//10)
ampsin = np.linspace(0,5,n//10)
ampcos = np.linspace(0,5,n//10)
ampsin[3:] = 0
ampcos[3:] = 0
y = 2.*T

# %%
# %matplotlib notebook

#for i in np.arange(100):
#    y = y + ampcos[i]*np.cos(omega[i]*T) + ampsin[i]*np.sin(omega[i]*T)  # y+= np.sin(omega[i]*T)
#
plt.plot(T,y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
#y=np.random.rand(1000)
f = np.fft.rfft(y,n)
f_shift = np.fft.fftshift(f)
freq = np.fft.fftshift(np.fft.rfftfreq(n,1/n))
plt.plot(freq,np.real(f_shift))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
plt.plot(np.fft.ifft(f))
plt.plot(y)
# Out:
# <img src="data:image/png;base64,..." width="640">
# /Users/greiner/Library/Python/3.8/lib/python/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
omega

# %%
np.exp(f[1])+np.exp(f[-1])

# %%
# %matplotlib notebook
plt.plot(ampsin)
plt.plot(ampcos)

# %%
f[2] = 10.

# %%
# %matplotlib notebook
plt.plot(f_shift.imag)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f_shift[300:] = 0.

# %%
# %matplotlib notebook
plt.plot(np.fft.irfft(f_shift))
# Out:
# <img src="data:image/png;base64,..." width="640">
